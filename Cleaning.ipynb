# %%
import pandas as pd
# import numpy as np

data = pd.read_csv('Data/BTC_Trades.csv')
df = pd.DataFrame(data)

# %%
df['datetime'] = pd.to_datetime(df['timestamp'], unit='ms')

# %%
df
# Out:
#          trade_id  contracts instrument_name  tick_direction  trade_seq  \
# 0       309606485        1.0   BTC-PERPETUAL               2  212510905
# 1       309606486      495.0   BTC-PERPETUAL               3  212510906
# 2       309606487      504.0   BTC-PERPETUAL               3  212510907
# 3       309606488      906.0   BTC-PERPETUAL               3  212510908
# 4       309606489      500.0   BTC-PERPETUAL               3  212510909
# ...           ...        ...             ...             ...        ...
# 685423  310282499        1.0      BTC-2AUG24               2      48826
# 685424  310282500      283.0   BTC-PERPETUAL               3  212910579
# 685425  310282501      378.0   BTC-PERPETUAL               2  212910580
# 685426  310282502      449.0   BTC-PERPETUAL               2  212910581
# 685427  310282503      129.0   BTC-PERPETUAL               2  212910582
#
#         mark_price  index_price  amount direction    price      timestamp  iv  \
# ...
